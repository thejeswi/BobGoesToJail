# %%
import nltk
import json
from database.schema import annotation

def parseAnn(annTxt):
    myAnn = annotation()
    for entity in annTxt.split("\n"):
        if len(entity) > 0 and entity[0] == "T":
            obj = entity.split("\t")

            entitySpecs = obj[1].split(" ")
            
            if obj[1].find(";") > 0:
                #print "Found ; seperated location in:", entity
                continue
            
            entity = entitySpecs[0]
            start = int(entitySpecs[1])
            end = int(entitySpecs[2])

            phrase = obj[2]

            myAnn.entityType = entity
            myAnn.start = start
            myAnn.end = end
            myAnn.phrase = phrase
            ann_db.insert_one(myAnn.out())
            
            print start, end, entity, phrase
        


from pymongo import MongoClient
import glob
import os

path = '/home/mlc/BobGoesToJail/corpus/lawTexts_en'

client = MongoClient()
client = MongoClient('localhost', 27017)
db = client['law_db']
ann_db = db.anns

for filename in glob.glob(os.path.join(path, '*.ann')):
    print filename
    fAnn = open(filename)
    parseAnn(fAnn.read())   
    fAnn.close()
# Out:
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/081.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/303.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/059a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/028.ann
# 41 43 FunctionOperation If
# 44 76 Attribute special personal characteristics
# 78 102 LawLink Section 14 subsection(1)
# 104
#  116 BinaryPredicate establishing
# 121 133 Bob perpetrators
# 134 147 Punishability punishability
# 148 178 BinaryPredicate are not present in relation to
# 183 190 Bob inciter
# 194 203 Bob accessory
# 191 193 FunctionOperation or
# 205 209 FunctionOperation then
# 210 213 BinaryPredicate his
# 214 224 Judgement punishment
# 225 255 BinaryPredicate shall be mitigated pursuant to
# 256 280 LawLink Section 49 subsection(1)
# 286 288 FunctionOperation If
# 387 391 FunctionOperation then
# 293 296 LawCorpus law
# 297 305 BinaryPredicate provides
# 311 343 Attribute special personal characteristics
# 344 353 BinaryPredicate aggravate
# 355 363 BinaryPredicate mitigate
# 367 374 BinaryPredicate exclude
# 375 385 Judgement punishment
# 392 396 LawCorpus this
# 397 416 BinaryPredicate shall apply only to
# 421 433 Bob participants
# 439 450 Bob perpetrator
# 458 465 Bob inciter
# 469 478 Bob accessory
# 451 453 FunctionOperation or
# 466 468 FunctionOperation or
# 491 495 Attribute they
# 480 490 BinaryPredicate as to whom
# 496 501 BinaryPredicate exist
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/123.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/059c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/270.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/200.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/140.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/225.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/257.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/109a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/145a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/075.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/211.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/109h.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/306c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/168.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/105.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/106.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/059b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/330d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/328.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/288.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/267.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/077.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/163.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/311.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/167a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/129.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/223.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/067.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/046a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/273.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/077d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/358.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/103.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/180a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/340.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/266.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/069a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/050.ann
# 46 58 Circumstance circumstance
# 59 93 BinaryPredicate which alone or together with other
# 94 107 Circumstance circumstances
# 108 137 BinaryPredicate justifies the assumption that
# 142 146 Act case
# 147 162 UnaryPredicate is less serious
# 163 166 FunctionOperation and
# 167 184 BinaryPredicate is simultaneously
# 187 228 Circumstance special statutory mitigating circumstance
# 229 234 BinaryPredicate under
# 235 245 LawLink Section 49
# 247 274 UnaryPredicate may only be considered once
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/085.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/325a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/230.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/293.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/069b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/091.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/107.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/283d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/324.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/283a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/060.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/315b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/092.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/073b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/077c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/170.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/107b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/070a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/132a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/313.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/318.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/203.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/231.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/074c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/068c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/265a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/053.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/145.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/155.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/176.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/176b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/132.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/174a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/138.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/109g.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/177.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/045a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/234.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/079b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/079.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/297.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/093.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/241.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/040.ann
# 36 40 Judgement fine
# 41 60 BinaryPredicate shall be imposed in
# 61 72 UnaryPredicate daily rates
# 74 76 Judgement It
# 77 92 BinaryPredicate shall amount to
# 93 106 FunctionOperation at least five
# 107 110 FunctionOperation and
# 112 114 FunctionOperation if
# 119 122 LawCorpus law
# 123 149 UnaryPredicate does not provide otherwise
# 151 172 FunctionOperation at most three hundred
# 173 176 FunctionOperation and
# 177 199 FunctionOperation sixty full daily rates
# 210 215 Organization court
# 216 226 BinaryPredicate determines
# 231 255 Judgement amount of the daily rate
# 257 282 BinaryPredicate taking into consideration
# 287 295 Attribute personal
# 296 299 FunctionOperation and
# 300 309 Attribute financial
# 310 323 Circumstance circumstances
# 324 326 BinaryPredicate of
# 331 342 Bob perpetrator
# 344 355 BinaryPredicate In doing so
# 357 359 Organization it
# 360 375 BinaryPredicate takes as a rule
# 380 398 Attribute average net income
# 409 420 Bob perpetrator
# 399
# 404 BinaryPredicate which
# 421 424 BinaryPredicate has
# 426 428 FunctionOperation or
# 429 439 BinaryPredicate could have
# 441 473 UnaryPredicate in one day as its starting point
# 477 487 Judgement daily rate
# 488 505 BinaryPredicate shall be fixed at
# 508 522 FunctionOperation minimum of two
# 523 526 FunctionOperation and
# 529 552 FunctionOperation maximum of ten thousand
# 553 565 Object German marks
# 572 586 UnaryPredicate In determining
# 591 612 UnaryPredicate daily rate the income
# 613 615 FunctionOperation of
# 620 631 Bob perpetrator
# 633 636 BinaryPredicate his
# 637 643 Attribute assets
# 644 647 FunctionOperation and
# 648 659 Attribute other bases
# 660 676 UnaryPredicate may be estimated
# 687 693 Attribute number
# 698 704 Attribute amount
# 694 697 FunctionOperation and
# 705 707 BinaryPredicate of
# 712 723 Judgement daily rates
# 724 745 BinaryPredicate shall be indicated in
# 750 758 Judgement decision
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/083.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/055.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/315c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/228.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/258a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/037.ann
# 26 68 NPA Truthful reports about the public sessions
# 83 95 BinaryPredicate indicated in
# 96 106 LawLink Section 36
# 107 109 FunctionOperation or
# 69 71 BinaryPredicate of
# 76 82 Organization bodies
# 110 126 Organization their committees
# 127 145 BinaryPredicate remain exempt from
# 146 159 LawCorpus any liability
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/291.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/120.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/107c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/179.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/239a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/078.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/033.ann
# 32 34 FunctionOperation If
# 39 50 Bob perpetrator
# 51 58 BinaryPredicate exceeds
# 63 90 LawCorpus limits of necessary defense
# 91 97 BinaryPredicate due to
# 98 107 UnaryPredicate confusion
# 109 113 UnaryPredicate fear
# 117 123 UnaryPredicate fright
# 114 116 FunctionOperation or
# 125 129 FunctionOperation then
# 130 132 Bob he
# 133 154 UnaryPredicate shall not be punished
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/154.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/258.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/181.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/056b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/316a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/336.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/030.ann
# 32 39 Bob Whoever
# 40 58 BinaryPredicate attempts to induce
# 59 61 FunctionOperation or
# 62 68 BinaryPredicate incite
# 69 76 John another
# 77 86 BinaryPredicate to commit
# 89 113 Act serious criminal offense
# 114 144 BinaryPredicate shall be punished according to
# 149 159 LawCorpus provisions
# 160 169 BinaryPredicate governing
# 170 202 Act serious criminal offense attempt
# 204 211 Circumstance However
# 216 226 Judgement punishment
# 227 257 BinaryPredicate shall be mitigated pursuant to
# 258 283 LawLink Section 49 subsection (1)
# 285 310 LawLink Section 23 subsection (3)
# 311 334 BinaryPredicate shall apply accordingly
# 341 348 Bob Whoever
# 349 361 BinaryPredicate declares his
# 362 373 UnaryPredicate willingness
# 375 382 Bob whoever
# 383 403 BinaryPredicate accepts the offer of
# 404 411 Bob another
# 413 415 FunctionOperation or
# 416 423 Bob whoever
# 424 435 BinaryPredicate agrees with
# 436 443 Bob another
# 444 453 BinaryPredicate to commit
# 454 456 FunctionOperation or
# 457 463 BinaryPredicate incite
# 468 478 NPA commission
# 479 481 BinaryPredicate of
# 484 508 Act serious criminal offense
# 510 537 BinaryPredicate shall be similarly punished
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/080.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/166.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/315d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/181b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/071.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/353b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/306a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/158.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/275.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/130a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/068.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/219a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/212.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/266b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/068b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/044.ann
# 20 22 FunctionOperation If
# 23 30 Bob someone
# 31 52 BinaryPredicate has been sentenced to
# 53 65 Judgement imprisonment
# 66 68 FunctionOperation or
# 71 75 Judgement fine
# 76 79 BinaryPredicate for
# 82 87 Act crime
# 88 93 BinaryPredicate which
# 94 96 Bob he
# 97 125 BinaryPredicate committed in connection with
# 130 140 UnaryPredicate driving of
# 157 159 FunctionOperation or
# 160 186 Act in violation of the duties
# 187 189 BinaryPredicate of
# 192 198 Bob driver
# 143 156 Object motor vehicle
# 199 201 BinaryPredicate of
# 204 217 Object motor vehicle
# 219 223 FunctionOperation then
# 228 233 Organization court
# 234 246 BinaryPredicate may prohibit
# 247 250 Bob him
# 251 263 BinaryPredicate from driving
# 264 282 Object all motor vehicles
# 284 286 FunctionOperation or
# 287 304 Object any specific type
# 306 321 UnaryPredicate in road traffic
# 322 325 BinaryPredicate for
# 328 368 Judgement period of from one month to three months
# 372 383 Judgement driving ban
# 384 424 BinaryPredicate shall be ordered, as a rule, in cases of
# 427 437 Judgement conviction
# 438 443 BinaryPredicate under
# 444 506 LawLink Sections 315c subsection (1), no. 1, letter (a) subsection (3)
# 508 510 FunctionOperation or
# 511 522 LawLink Section 316
# 523 525 FunctionOperation if
# 526 540 BinaryPredicate there has been
# 541 577 Judgement no withdrawal of permission to drive
# 578 589 BinaryPredicate pursuant to
# 590 600 LawLink Section 69
# 609 620 Judgement driving ban
# 621 643 BinaryPredicate shall take effect when
# 648 656 Judgement judgment
# 657 670 UnaryPredicate becomes final
# 672 715 Object National and international drivers licenses
# 716 725 BinaryPredicate issued by
# 728 751 Organization German public authority
# 752 768 BinaryPredicate shall be kept in
# 769 785 Organization official custody
# 786 802 UnaryPredicate for its duration
# 804 808 LawLink This
# 809 825 BinaryPredicate shall also apply
# 826 828 FunctionOperation if
# 833 848 Object drivers license
# 849 862 BinaryPredicate was issued by
# 865 881 Organization public authority
# 882 884 BinaryPredicate of
# 887 921 Organization member state of the European Union
# 922 924 BinaryPredicate or
# 925 996 Organization another signatory state of the Convention on the European Economic Area
# 998 1008 BinaryPredicate as long as
# 1013 1019 Bob holder
# 1020 1023 BinaryPredicate has
# 1024 1057 UnaryPredicate his ordinary residence in Germany
# 1063 1074 Judgement driving ban
# 1075 1095 BinaryPredicate shall be endorsed on
# 1096 1126 Object other foreign drivers licenses
# 1133 1135 FunctionOperation If
# 1138 1153 Object drivers license
# 1154 1170 BinaryPredicate is to be kept in
# 1171 1187 Judgement official custody
# 1188 1190 FunctionOperation or
# 1195 1206 Judgement driving ban
# 1207 1218 BinaryPredicate endorsed on
# 1221 1244 Object foreign drivers license
# 1246 1250 FunctionOperation then
# 1255 1274 Judgement term of prohibition
# 1275 1299 BinaryPredicate shall be calculated from
# 1304
#  1329 UnaryPredicate day that this takes place
# 1335 1339 Time time
# 1340 1348 BinaryPredicate in which
# 1353 1364 Bob perpetrator
# 1365 1375 BinaryPredicate is held in
# 1376 1383 Judgement custody
# 1384 1386 BinaryPredicate in
# 1390 1401 Organization institution
# 1402 1413 BinaryPredicate pursuant to
# 1417 1422 Judgement order
# 1423 1425 BinaryPredicate of
# 1428 1444 Organization public authority
# 1445 1473 BinaryPredicate shall not be calculated into
# 1478 1501 Judgement term of the prohibition
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/097b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/056f.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/068e.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/322.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/242.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/312.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/333.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/287.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/325.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/309.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/058.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/264.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/265.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/165.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/074.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/344.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/090a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/234a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/056d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/031.ann
# 47 54 Bob Whoever
# 55 66 Attribute voluntarily
# 72 81 BinaryPredicate renounces
# 86 93 NPA attempt
# 94 103 BinaryPredicate to induce
# 104 111 John another
# 112 121 BinaryPredicate to commit
# 124 148 Act serious criminal offense
# 150 153 FunctionOperation and
# 154 160 BinaryPredicate averts
# 161 180 Circumstance any existing danger
# 181 185 BinaryPredicate that
# 190 195 John other
# 196 206 BinaryPredicate may commit
# 211 214 Act act
# 220 225 FunctionOperation after
# 226 228 Bob he
# 229 267 BinaryPredicate has declared his willingness to commit
# 270 294 Act serious criminal offense
# 296 305 BinaryPredicate renounces
# 306 314 UnaryPredicate his plan
# 316 318 FunctionOperation or
# 323 328 FunctionOperation after
# 329 331 Bob he
# 332 348 BinaryPredicate agrees to commit
# 351 375 Act serious criminal offense
# 377 379 FunctionOperation or
# 380 400 BinaryPredicate accepts the offer of
# 401 408 Bob another
# 409 418 BinaryPredicate to commit
# 421 445 Act serious criminal offense
# 447 473 BinaryPredicate prevents the commission of
# 478 481 Act act
# 484 511 BinaryPredicate shall not be punished under
# 512 522 LawLink Section 30
# 529 531 FunctionOperation If
# 536 539 Act act
# 540 577 BinaryPredicate does not take place due in no part to
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/184.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/245.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/227.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/067b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/074d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/303b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/248c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/076.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/083a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/243.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/219b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/326.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/265b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/077a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/097.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/276.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/244a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/010.ann
# 54 62 LawCorpus This law
# 63 77 BinaryPredicate shall apply to
# 78 89 Act the acts of
# 90 116 Bob juveniles and young adults
# 117 140 BinaryPredicate only to the extent that
# 141 162 Organization the Jvenile Court Law
# 163 189 UnaryPredicate does not provide otherwise
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/290.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/126.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/125a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/330a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/134.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/202.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/043a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/108.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/330.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/068f.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/160.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/183.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/220a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/181a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/032.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/109k.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/056g.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/221.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/009.ann
# 24 30 Act An act
# 31 43 UnaryPredicate is committed
# 44 58 Location at every place
# 59 74 Bob the perpetrator
# 75 80 UnaryPredicate acted
# 81 83 BinaryPredicate or
# 85 107 UnaryPredicate in case of an omission
# 110 127 Act should have acted
# 129 131 BinaryPredicate or
# 196 198 BinaryPredicate or
# 132 151 Act at which the result
# 153 188 UnaryPredicate which is an element of the offense,
# 189 195 UnaryPredicate occurs
# 199 245 Act should occur according to the understanding of
# 246 261 Bob the perpetrator
# 268 295 Act Incitement or accessoryship
# 296 320 BinaryPredicate is committed not only at
# 325 330 Location place
# 331 336 BinaryPredicate where
# 341
#  358 Act act was committed
# 360 368 BinaryPredicate but also
# 369 383 Location at every place
# 384 389 BinaryPredicate where
# 390 414 Bob the inciter or accessory
# 415 420 UnaryPredicate acted
# 421 424 BinaryPredicate or,
# 425 447 UnaryPredicate in case of an omission
# 449 466 Act should have acted
# 470 507 BinaryPredicate where, according to his understanding
# 513 516 Act act
# 517 543 UnaryPredicate should have been committed
# 467 469 BinaryPredicate or
# 545 547 BinaryPredicate If
# 548 572 Bob the inciter or accessory
# 576 582 Act an act
# 583 589 Location abroad
# 596 608 Location domestically
# 590 595 BinaryPredicate acted
# 615 634 LawCorpus German criminal law
# 635 649 BinaryPredicate shall apply to
# 654 681 Act incitement or accessoryship
# 610 614 BinaryPredicate then
# 683 690 BinaryPredicate even if
# 691 698 Act the act
# 699 726 BinaryPredicate is not punishable according
# 730 737 LawCorpus the law
# 741 750 Location the place
# 751 768 Act of its commission
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/157.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/266a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/278.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/353.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/097a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/216.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/249.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/192.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/173.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/086.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/335.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/150.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/250.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/174c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/147.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/068g.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/339.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/045.ann
# 91 98 Bob Whoever
# 99 115 BinaryPredicate is sentenced for
# 118 142 Act serious criminal offense
# 143 145 BinaryPredicate to
# 146 180 Judgement imprisonment for at least one year
# 181 195 BinaryPredicate shall lose for
# 198 288 Judgement period of five years the capacity to hold public office and attain public electoral rights
# 299 304 Organization court
# 305 316 BinaryPredicate may deprive
# 321 337 Bob convicted person
# 338 340 BinaryPredicate of
# 345 368 BinaryPredicate capacities indicated in
# 369 383 LawLink subsection (1)
# 384 422 Judgement for a period of from two to five years
# 424 437 BinaryPredicate to the extent
# 442 445 LawCorpus law
# 446 470 UnaryPredicate specifically so provides
# 477 528 Judgement With the loss of the capacity to hold public office
# 533 549 Bob convicted person
# 550 575 BinaryPredicate shall simultaneously lose
# 580
#  608 Attribute corresponding legal statuses
# 609 612 FunctionOperation and
# 613 632 Attribute rights he possesses
# 639 702 Judgement With the loss of the capacity to attain public electoral rights
# 708 724 Bob convicted person
# 725 750 BinaryPredicate shall simultaneously lose
# 755 783 Attribute corresponding legal statuses
# 784 787 FunctionOperation and
# 788 807 Attribute rights he possesses
# 808 821 BinaryPredicate to the extent
# 826 829 LawCorpus law
# 830 856 UnaryPredicate does not otherwise provide
# 867 872 Organization court
# 873 884 BinaryPredicate may deprive
# 889 905 Bob convicted person
# 906 908 BinaryPredicate of
# 913 953 LawCorpus right to elect or vote in public matters
# 954 957 BinaryPredicate for
# 960 992 Judgement period of from two to five years
# 994 1007 BinaryPredicate to the extent
# 1012 1015 LawCorpus law
# 1016 1040 UnaryPredicate specifically so provides
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/057b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/086a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/353a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/277.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/283b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/005.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/078c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/131.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/002.ann
# 34 76 Punishability punishment and its collateral consequences
# 77 94 BinaryPredicate are determined by
# 95 120 LawCorpus the law which is in force
# 121 143 UnaryPredicate at the time of the act
# 150 178 Punishability If the threatened punishment
# 179 222 UnaryPredicate is amended during the commission of the act
# 224 274 UnaryPredicate then the law shall be applicable which is in force
# 275 307 UnaryPredicate at the time the act is completed
# 321 333 LawCorpus law in force
# 365 390 UnaryPredicate is amended before judgmen
# 393 438 Judgement then the most lenient law shall be applicable
# 314 316 BinaryPredicate If
# 445 450 LawCorpus A law
# 452 485 UnaryPredicate which was intended to be in force
# 486 513 UnaryPredicate only for a determinate time
# 334 364 Act upon the completion of the act
# 515 552 Judgement shall be applicable to acts committed
# 553 608 BinaryPredicate while it was in force, even if it is no longer in force
# 610 620 LawCorpus This shall
# 621 644 BinaryPredicate not apply to the extent
# 645 650 LawCorpus a law
# 651 669 UnaryPredicate provides otherwise
# 701 702 LawLink 4
# 692 699 FunctionOperation through
# 676 691 LawLink Subsections (1)
# 704 733 BinaryPredicate shall apply, correspondingly,
# 734 784 UnaryPredicate to forfeiture, confiscation and rendering unusable
# 798 805 LawCorpus the law
# 791 797 BinaryPredicate Unless
# 806 824 UnaryPredicate provides otherwise
# 826 875 UnaryPredicate decisions as to measures of reform and prevention
# 876 897 BinaryPredicate shall be according to
# 902 905 LawCorpus law
# 906 947 UnaryPredicate which is in force at the time of judgment
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/219.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/204.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/098.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/306e.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/301.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/307.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/019.ann
# 55 62 Bob Whoever
# 90 92 BinaryPredicate is
# 93 120 FunctionOperation under fourteen years of age
# 121 157 UnaryPredicate lacks capacity to be adjudged guilty
# 63 81 BinaryPredicate upon commission of
# 86 89 Act act
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/012.ann
# 69 94 Act Serious criminal offenses
# 95 98 BinaryPredicate are
# 108 112 Act acts
# 99 107 UnaryPredicate unlawful
# 113 135 BinaryPredicate that are punishable by
# 138 182 Judgement minimum of imprisonment for one year or more
# 189 219 Act Less serious criminal offenses
# 220 223 BinaryPredicate are
# 224 232 UnaryPredicate unlawful
# 233 237 Act acts
# 238 260 BinaryPredicate that are punishable by
# 263 313 Judgement minimum of a lesser term of imprisonment or a fine
# 320 331 NPA Aggravation
# 335 345 NPA mitigation
# 332 334 BinaryPredicate or
# 347 389 BinaryPredicate which are provided under the provisions of
# 394 406 LawCorpus General Part
# 410 454 LawCorpus for especially serious or less serious cases
# 407 409 BinaryPredicate or
# 456
#  498 UnaryPredicate shall be irrelevant to this classification
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/125.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/067c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/066.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/104.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/090.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/046.ann
# 51 56 Fault guilt
# 57 59 BinaryPredicate of
# 64 75 Bob perpetrator
# 76 97 BinaryPredicate is the foundation for
# 98 120 Judgement determining punishment
# 144 154 Judgement punishment
# 155 182 BinaryPredicate will be expected to have on
# 187 199 Bob perpetrators
# 200 222 UnaryPredicate future life in society
# 223 242 UnaryPredicate shall be considered
# 126 133 Circumstance effects
# 134 139 BinaryPredicate which
# 249 269 Judgement In its determination
# 274 279 Organization court
# 280 300 BinaryPredicate shall counterbalance
# 305 318 Circumstance circumstances
# 319 346 BinaryPredicate which speak for and against
# 351 362 Bob perpetrator
# 364 375 UnaryPredicate In doing so
# 376 422 BinaryPredicate consideration shall be given in particular to:
# 445 447 BinaryPredicate of
# 452 463 Bob perpetrator
# 428 435 Attribute motives
# 436 439 FunctionOperation and
# 440 444 Attribute aims
# 470 483 Attribute state of mind
# 484 496 BinaryPredicate reflected in
# 501 504 Act act
# 505 508 FunctionOperation and
# 513 524 Attribute willfulness
# 525 536 BinaryPredicate involved in
# 537 540 Act its
# 541 551 UnaryPredicate commission
# 558 574 Attribute extent of breach
# 575 577 BinaryPredicate of
# 578 588 Act any duties
# 595 614 Attribute manner of execution
# 615 618 FunctionOperation and
# 623 644 Attribute culpable consequences
# 645 647 FunctionOperation of
# 652 655 Act act
# 662 674 Bob perpetrators
# 675 688 Attribute prior history
# 690 730 Circumstance his personal and financial circumstances
# 732 742 BinaryPredicate as well as
# 744 755 UnaryPredicate his conduct
# 756 761 BinaryPredicate after
# 766 769 Act act
# 771 803 BinaryPredicate particularly his efforts to make
# 804 815 NPA restitution
# 816 819 BinaryPredicate for
# 824 828 Act harm
# 829 835 UnaryPredicate caused
# 836 846 BinaryPredicate as well as
# 851 863 Bob perpetrators
# 864 871 NPA efforts
# 872 882 BinaryPredicate to achieve
# 883 892 Attribute mediation
# 893 897 BinaryPredicate with
# 902 917 John aggrieved party
# 924 937 Circumstance Circumstances
# 938 977 BinaryPredicate which are already statutory elements of
# 982 989 Act offense
# 990 1011 UnaryPredicate may not be considered
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/218.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/156.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/014.ann
# 30 37 Bob someone
# 27 29 FunctionOperation If
# 38 42 BinaryPredicate acts
# 48 50 BinaryPredicate as
# 54 71 John entity authorized
# 72 84 BinaryPredicate to represent
# 87 99 John legal person
# 100 105 BinaryPredicate or as
# 108 117 BinaryPredicate member of
# 118 132 Organization such an entity
# 138
#  140 BinaryPredicate as
# 143 161 John partner authorized
# 162 174 BinaryPredicate to represent
# 177 199 Organization commercial partnership
# 208 210 BinaryPredicate as
# 213 237 John statutory representative
# 238 240 BinaryPredicate of
# 241 248 John another
# 251 255 FunctionOperation then
# 258 261 LawCorpus law
# 263 281 BinaryPredicate according to which
# 282 309 Attribute special personal attributes
# 311 324 Attribute relationships
# 328 376 Attribute circumstances (special personal characteristics)
# 377 395 BinaryPredicate forms the basis of
# 396 409 Punishability punishability
# 411 438 BinaryPredicate shall also be applicable to
# 443 457 John representative
# 459 461 FunctionOperation if
# 468 483 Attribute characteristics
# 484 511 BinaryPredicate do not, in deed, pertain to
# 512 515 John him
# 517 532 BinaryPredicate but exist as to
# 537 543 John person
# 544 555 UnaryPredicate represented
# 562 564 FunctionOperation If
# 569 574 John owner
# 575 577 BinaryPredicate of
# 580 588 Organization business
# 589 591 BinaryPredicate or
# 592 623 John someone otherwise so authorized
# 629 640 BinaryPredicate commissions
# 643 649 Bob person
# 650 659 BinaryPredicate to manage
# 662 670 Organization business
# 672 691 UnaryPredicate in whole or in part
# 693 695 BinaryPredicate or
# 700 721 BinaryPredicate expressly commissions
# 724 730 Bob person
# 731 774 UnaryPredicate to perform on his own responsibility duties
# 775 797 BinaryPredicate which are incumbent on
# 802 807 John owner
# 808 810 BinaryPredicate of
# 815 823 Organization business
# 826 832 FunctionOperation and if
# 838 844 Bob person
# 845 865 BinaryPredicate acts on the basis of
# 871 881 NPA commission
# 883 887 FunctionOperation then
# 890 893 LawCorpus law
# 895 913 BinaryPredicate according to which
# 914 946 Attribute special personal characteristics
# 947 963 BinaryPredicate are the basis of
# 964 977 Punishability punishability
# 978 1005 BinaryPredicate shall also be applicable to
# 1010 1016 John person
# 1017 1029 UnaryPredicate commissioned
# 1031 1033 FunctionOperation if
# 1040 1055 Attribute characteristics
# 1056 1082 BinaryPredicate do not, indeed, pertain to
# 1083 1086 John him
# 1088 1103 BinaryPredicate but exist as to
# 1108 1113 John owner
# 1114 1116 BinaryPredicate of
# 1121 1129 Organization business
# 1131 1152 BinaryPredicate Within the meaning of
# 1153 1163 LawLink Sentence 1
# 1168 1178 Organization enterprise
# 1179 1199 BinaryPredicate is the equivalent of
# 1202 1210 Organization business
# 1212 1214 FunctionOperation If
# 1215 1222 John someone
# 1223 1243 BinaryPredicate acts on the basis of
# 1246 1270 NPA corresponding commission
# 1278 1284 Organization agency
# 1271 1274 BinaryPredicate for
# 1285 1309 BinaryPredicate
# which performs duties of
# 1310 1331 NPA public administration
# 1333 1337 FunctionOperation then
# 1338 1376 LawLink Sentence 1 (3) Subsections (1) and (2)
# 1377 1404 BinaryPredicate shall also be applicable if
# 1409 1418 Act legal act
# 1425 1445 BinaryPredicate was intended to form
# 1450 1486 UnaryPredicate basis of the power of representation
# 1487 1489 BinaryPredicate or
# 1494 1508 UnaryPredicate agency is void
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/181c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/073e.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/262.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/271.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/067f.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/006.ann
# 65 84 LawCorpus German criminal law
# 85 119 BinaryPredicate shall further apply, regardless of
# 124 127 LawCorpus law
# 128 140 Location of the place
# 141 160 Organization of their commission
# 162 178 BinaryPredicate to the following
# 179 183 Act acts
# 184 200 UnaryPredicate committed abroad
# 210 218 Act genocide
# 220 232 LawLink Section 220a
# 243 268 Act serious criminal offenses
# 269 278 BinaryPredicate involving
# 279 293 Attribute nuclear energy
# 295 305 Attribute explosives
# 310 319 Attribute radiation
# 320 334 BinaryPredicate in cases under
# 335 347 LawLink Sections 307
# 352 378 LawLink 308 subsections (1) to (4)
# 379 405 LawLink Section 309 subsection (2)
# 431 467 Act assaults against air and sea traffic
# 469 481 LawLink Section 316c
# 492 519 Act trafficking in human beings
# 521 533 LawLink Section 180b
# 539 574 Act serious trafficking in human beings
# 576 587 LawLink Section 181
# 410 421 LawLink Section 310
# 598 636 Act unauthorized distribution of narcotics
# 646 684 Act dissemination of pornographic writings
# 685 699 BinaryPredicate in cases under
# 700 734 LawLink Section 184 subsection (3) and (4)
# 784 796 LawLink Sections 146
# 798 801 LawLink 151
# 805 808 LawLink 152
# 744 758 Act counterfeiting
# 759 767 Object of money
# 772 782 Object securities
# 811 824 Object payment cards
# 829 845 Object blank Eurochecks
# 895 912 Act their preparation
# 884 894 BinaryPredicate as well as
# 914 926 LawLink Sections 149
# 927 930 LawLink 151
# 931 934 LawLink 152
# 939 958 LawLink 152a subsection (5)
# 968 981 Act subsidy fraud
# 983 994 LawLink Section 264
# 1005 1009 Act acts
# 1010 1032 BinaryPredicate which, on the basis of
# 1036 1102 LawCorpus international agreement binding on the Federal Republic of Germany
# 1104 1157 UnaryPredicate shall also be prosecuted if they are committed abroad
# 876 878 FunctionOperation to
# 847 875 LawLink Section 152a subsections (1)
# 879 881 LawLink (4
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/108c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/088.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/121.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/283c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/136.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/302.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/164.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/263a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/029.ann
# 49 54 UnaryPredicate Every
# 55 66 Bob participant
# 67 101 BinaryPredicate shall be punished according to his
# 102 111 Fault own guilt
# 112 127 BinaryPredicate irrespective of
# 132 137 Fault guilt
# 138 140 BinaryPredicate of
# 145 150 John other
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/100.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/109.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/186.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/188.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/260.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/007.ann
# 51 70 LawCorpus German criminal law
# 71 85 BinaryPredicate shall apply to
# 86 90 Act acts
# 92 127 BinaryPredicate which were committed abroad against
# 130 136 John German
# 145
#  148 Act act
# 138 140 BinaryPredicate if
# 149 165 BinaryPredicate is punishable at
# 170 192 Location place of its commissio
# 201 224 Location place of its commission
# 194 196 BinaryPredicate or
# 225 241 BinaryPredicate is subject to no
# 242 266 LawCorpus criminal law enforcement
# 273 292 LawCorpus German criminal law
# 293 307 BinaryPredicate shall apply to
# 308 318 Act other acts
# 320 350 BinaryPredicate which were committed abroad if
# 355 358 Act act
# 359 375 BinaryPredicate is punishable at
# 380 403 Location place of its commission
# 411 434 Location place of its commission
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/314.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/133.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/261.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/106a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/187.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/246.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/321.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/026.ann
# 15 22 Bob Whoever
# 23 44 BinaryPredicate intentionally induces
# 45 52 Bob another
# 53 76 BinaryPredicate to intentionally commit
# 80 92 Act unlawful act
# 94 99 BinaryPredicate shall
# 116 127 BinaryPredicate be punished
# 101 103 BinaryPredicate as
# 107 114 Attribute inciter
# 132 139 FunctionOperation same as
# 142 153 Bob perpetrator
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/236.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/law_en.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/056e.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/107a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/109i.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/035.ann
# 28 35 Bob Whoever
# 37 47 BinaryPredicate faced with
# 51 69 BinaryPredicate imminent danger to
# 70 74 UnaryPredicate life
# 76 80 UnaryPredicate limb
# 84 91 UnaryPredicate freedom
# 92 125 UnaryPredicate which cannot otherwise be averted
# 127 134 BinaryPredicate commits
# 138 150 Act unlawful act
# 151 159 BinaryPredicate to avert
# 164 170 Circumstance danger
# 171 175 BinaryPredicate from
# 176 183 Bob himself
# 187 195 John relative
# 196 198 FunctionOperation or
# 199 218 John person close to him
# 220 224 BinaryPredicate acts
# 225 232 FunctionOperation without
# 233 238 Fault guilt
# 240 244 LawLink This
# 245 263 BinaryPredicate shall not apply to
# 268 274 Attribute extent
# 275 279 BinaryPredicate that
# 284 295 Bob perpetrator
# 296 319 BinaryPredicate could be expected under
# 324 337 Circumstance circumstances
# 338 356 BinaryPredicate to assume the risk
# 358 371 BinaryPredicate in particular
# 373 380 BinaryPredicate because
# 381 391 Bob he himself
# 392 398 BinaryPredicate caused
# 403 409 Circumstance danger
# 410 412 FunctionOperation or
# 413 450 Circumstance stood in a special legal relationship
# 452 459 Circumstance however
# 464 474 Judgement punishment
# 475 503 BinaryPredicate may be mitigated pursuant to
# 532 534 FunctionOperation if
# 539 550 Bob perpetrator
# 551 586 BinaryPredicate was not required to assume the risk
# 587 591 BinaryPredicate with
# 592 631 UnaryPredicate respect to a special legal relationship
# 638 645 FunctionOperation If upon
# 646 659 BinaryPredicate commission of
# 664 667 Act act
# 672 683 Bob perpetrator
# 684 707 BinaryPredicate mistakenly assumes that
# 708 721 Circumstance circumstances
# 722 727 UnaryPredicate exist
# 729 757 BinaryPredicate which would excuse him under
# 758 772 LawLink subsection (1)
# 774 776
# Bob he
# 777 798 BinaryPredicate will only be punished
# 800 802 FunctionOperation if
# 803 805 Bob he
# 806 824 BinaryPredicate could have avoided
# 829 836 Act mistake
# 842 852 Judgement punishment
# 853 883 BinaryPredicate shall be mitigated pursuant to
# 884 909 LawLink Section 49 subsection (1)
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/113.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/073a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/330b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/022.ann
# 24 31 Bob Whoever
# 33 51 BinaryPredicate in accordance with
# 52 72 BinaryPredicate his understanding of
# 77 80 Act act
# 82 113 BinaryPredicate takes an immediate step towards
# 153 160 LawCorpus offense
# 118 145 NPA realization of the elements
# 146 148 BinaryPredicate of
# 162 180 BinaryPredicate attempts to commit
# 183 188 Act crime
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/102.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/042.ann
# 28 30 FunctionOperation If
# 35 51 Bob convicted person
# 53 59 BinaryPredicate due to
# 60 72 Attribute his personal
# 73 75 FunctionOperation or
# 76 85 Attribute financial
# 86 99 Circumstance circumstances
# 101 126 BinaryPredicate cannot be expected to pay
# 131 135 Judgement fine
# 136 147 BinaryPredicate immediately
# 153 158 Organization court
# 159 170 BinaryPredicate shall grant
# 171 174 Bob him
# 177 193 Judgement payment deadline
# 194 196 FunctionOperation or
# 197 202 BinaryPredicate allow
# 203 206 Bob him
# 207 238 Judgement to pay in specified instalments
# 244
#  249 Organization court
# 250 269 BinaryPredicate may also order that
# 274 323 Judgement privilege of paying the fine in fixed instalments
# 324 336 BinaryPredicate be withdrawn
# 337 339 FunctionOperation if
# 344 360 Bob convicted person
# 361 373 BinaryPredicate fails to pay
# 377 395 Judgement instalment in time
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/174b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/334.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/317.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/159.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/183a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/279.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/068d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/139.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/149.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/289.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/068a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/109f.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/348.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/315a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/057.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/244.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/041.ann
# 36 41 FunctionOperation If by
# 46 49 Act act
# 54 65 Bob perpetrator
# 66 74 UnaryPredicate enriched
# 76 78 FunctionOperation or
# 79 102 UnaryPredicate tried to enrich himself
# 104 108 FunctionOperation then
# 111 115 Judgement fine
# 117 161 UnaryPredicate which otherwise would have been inapplicable
# 162 164 FunctionOperation or
# 165 178 UnaryPredicate only optional
# 180 208 BinaryPredicate may be imposed collateral to
# 209 221 Judgement imprisonment
# 223 225 FunctionOperation if
# 226 228 Judgement it
# 229 270 BinaryPredicate is appropriate, taking into consideration
# 275 283 Attribute personal
# 284 287 FunctionOperation and
# 288 297 Attribute financial
# 298 311 Circumstance circumstances
# 312 314 BinaryPredicate of
# 319 330 Bob perpetrator
# 332 336 LawLink This
# 337 352 BinaryPredicate shall not apply
# 353 355 FunctionOperation if
# 360 365 Organization court
# 366 373 BinaryPredicate imposes
# 376 389 Judgement property fine
# 390 401 BinaryPredicate pursuant to
# 402 413 LawLink Section 43a
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/104a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/259.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/076a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/074e.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/323c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/069.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/300.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/077b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/017.ann
# 19 26 FunctionOperation If upon
# 27 48 Act commission of the act
# 53 64 Bob perpetrator
# 65 92 BinaryPredicate lacks the appreciation that
# 93 95 Bob he
# 96 120 UnaryPredicate is doing something wrong
# 122 124 Bob he
# 125 146 BinaryPredicate acts without guilt if
# 147 149 Bob he
# 150 169 BinaryPredicate was unable to avoid
# 175 182 Act mistake
# 184 186 FunctionOperation If
# 191 202 Bob perpetrator
# 203 221 BinaryPredicate could have avoided
# 226 233 Act mistake
# 239 249 Judgement punishment
# 250 278 BinaryPredicate may be mitigated pursuant to
# 279 304 LawLink Section 49 subsection (1)
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/056c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/145d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/059.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/074f.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/063.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/226.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/305.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/260a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/316.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/357.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/015.ann
# 63 76 UnaryPredicate is punishable
# 43 62 Act intentional conduct
# 38 42 UnaryPredicate Only
# 78 84 BinaryPredicate unless
# 89 92 LawCorpus law
# 93 122 UnaryPredicate expressly provides punishment
# 123 126 BinaryPredicate for
# 127 144 Act negligent conduct
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/323a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/073d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/353d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/284.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/190.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/124.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/205.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/239b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/108e.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/142.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/352.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/127.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/094.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/332.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/193.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/025.ann
# 21 28 Bob Whoever
# 29 36 BinaryPredicate commits
# 41 46 Act crime
# 47 54 BinaryPredicate himself
# 55 57 FunctionOperation or
# 58 65 BinaryPredicate through
# 66 73 John another
# 74 94 BinaryPredicate shall be punished as
# 97 108 Bob perpetrator
# 115 131 FunctionOperation If more than one
# 132 138 Bob person
# 139 145 BinaryPredicate commit
# 150 155 Act crime
# 156 163 BinaryPredicate jointly
# 165 169 Bob each
# 170 190 BinaryPredicate shall be punished as
# 193 221 Bob perpetrator (co-perpetrator)
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/202a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/240.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/343.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/109d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/282.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/199.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/067e.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/320.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/092a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/092b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/067g.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/003.ann
# 34 53 LawCorpus German criminal law
# 54 68 BinaryPredicate shall apply to
# 69 73 Act acts
# 75 108 UnaryPredicate which were committed domestically
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/039.ann
# 43 55 Judgement Imprisonment
# 56 76 FunctionOperation for less than a year
# 77 99 BinaryPredicate shall be determined in
# 100 110 UnaryPredicate full weeks
# 111 114 FunctionOperation and
# 115 121 UnaryPredicate months
# 123 135 Judgement imprisonment
# 136 155 FunctionOperation for a longer period
# 157 159 BinaryPredicate in
# 160 171 UnaryPredicate full months
# 172 175 FunctionOperation and
# 176 181 UnaryPredicate years
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/074a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/077e.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/285.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/038.ann
# 31 43 Judgement Imprisonment
# 44 63 BinaryPredicate is for a fixed term
# 64 66 FunctionOperation if
# 71 74 LawCorpus law
# 75 95 BinaryPredicate does not provide for
# 96 117 Judgement imprisonment for life
# 128 146 UnaryPredicate maximum fixed term
# 147 149 BinaryPredicate of
# 150 162 Judgement imprisonment
# 163 165 BinaryPredicate is
# ...
# 507 540 BinaryPredicate with which it was to be committed
# 552 564 BinaryPredicate may withhold
# 565 575 Judgement punishment
# 576 578 FunctionOperation or
# 579 609 BinaryPredicate in its own discretion mitigate
# 614 624 Judgement punishment
# 626 650 LawLink Section 49 subsection(2)
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/108a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/151.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/045b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/269.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/090b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/239.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/018.ann
# 65 67 FunctionOperation If
# 72 75 LawCorpus law
# 76 81 BinaryPredicate links
# 84 107 Judgement more serious punishment
# 108 110 BinaryPredicate to
# 113 133 Attribute particular result of
# 138 141 Act act
# 143 153 BinaryPredicate it affects
# 158 169 Bob perpetrator
# 177 184 Bob inciter
# 170 172 BinaryPredicate or
# 188 197 Bob accessory
# 185 187 BinaryPredicate or
# 198 205 FunctionOperation only if
# 206
#  208 Bob he
# 209 237 BinaryPredicate can at least be charged with
# 238 248 Act negligence
# 249 274 UnaryPredicate in relation to the result
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/345.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/286.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/082.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/078b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/329.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/021.ann
# 46 48 FunctionOperation If
# 53 64 BinaryPredicate capacity of
# 69 80 Bob perpetrator
# 81 94 BinaryPredicate to appreciate
# 99 111 Punishability wrongfulness
# 112 114 BinaryPredicate of
# 119 122 Act act
# 123 125 FunctionOperation or
# 126 169 Act to act in accordance with such appreciation
# 170 202 BinaryPredicate is substantially diminished upon
# 203 224 Act commission of the act
# 225 231 BinaryPredicate due to
# 232 263 BinaryPredicate one of the reasons indicated in
# 264 274 LawLink Section 20
# 276 280 FunctionOperation then
# 285 295 Judgement punishment
# 296 324 BinaryPredicate may be mitigated pursuant to
# 325 350 LawLink Section 49 subsection (1)
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/096.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/276a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/061.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/308.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/087.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/323b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/224.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/316c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/303c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/152.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/148.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/080a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/182.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/251.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/004.ann
# 54 73 LawCorpus German criminal law
# 74 100 BinaryPredicate shall apply, regardless of
# 105 108 LawCorpus law
# 109 121 Location of the place
# 122 127 BinaryPredicate where
# 132 135 Act act
# 136 149 UnaryPredicate was committed
# 154 158 Act acts
# 151 153 BinaryPredicate to
# 159 180 BinaryPredicate which are committed o
# 184 188 Location ship
# 198 206 Location aircraft
# 189 194 BinaryPredicate or in
# 208 232 BinaryPredicate which is entitled to fly
# 237 249 Object federal flag
# 250 252 BinaryPredicate or
# 257 309 Object national insignia of the Federal Republic of Germany
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/078a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/106b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/145c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/095.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/218b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/294.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/180.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/338.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/184c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/305a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/330c.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/281.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/089.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/100a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/108d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/283.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/295.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/298.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/274.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/064.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/306d.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/206.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/213.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/056.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/331.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/072.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/073.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/292.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/185.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/316b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/057a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/109e.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/047.ann
# 64 69 Organization court
# 70 80 BinaryPredicate may impose
# 81 118 Judgement imprisonment for less than six months
# 119 128 BinaryPredicate only when
# 129 150 Circumstance special circumstances
# 151 167 BinaryPredicate exist, either in
# 172 175 Act act
# 176 178 FunctionOperation or
# 183 194 Attribute personality
# 195 197 BinaryPredicate of
# 202 213 Bob perpetrator
# 215 225 BinaryPredicate which make
# 230 256 Judgement imposition of imprisonment
# 257 292 BinaryPredicate indispensable to exert influence on
# 297 308 Bob perpetrator
# 309 311 FunctionOperation or
# 312 321 BinaryPredicate to defend
# 326 337 LawCorpus legal order
# 344 346 FunctionOperation If
# 351 354 LawCorpus law
# 355 375 BinaryPredicate does not provide for
# 378 382 Judgement fine
# 383 386 FunctionOperation and
# 389 431 Judgement term of imprisonment of six months or more
# 432 450 UnaryPredicate has been ruled out
# 456 461 Organization court
# 462 474 BinaryPredicate shall impose
# 477 481 Judgement fine
# 482 484 FunctionOperation if
# 489 515 Judgement imposition of imprisonment
# 516 548 BinaryPredicate is not indispensable pursuant to
# 549 563 LawLink subsection (1)
# 565 567 FunctionOperation If
# 572 575 LawCorpus law
# 576 588 BinaryPredicate provides for
# 592 631 Judgement increased minimum term of imprisonment,
# 636
#  648 Judgement minimum fine
# 649 668 BinaryPredicate in cases covered by
# 669 679 LawLink sentence 1
# 680 696 BinaryPredicate is determined by
# 701 740 Judgement minimum prescribed term of imprisonment
# 742 760 Judgement thirty daily rates
# 761 785 BinaryPredicate shall thus correspond to
# 786 808 Judgement one month imprisonment
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/174.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/264a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/303a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/355.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/101.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/194.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/218a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/020.ann
# 70 77 Bob Whoever
# 78 96 BinaryPredicate upon commission of
# 101 104 Act act
# 138 150 Punishability wrongfulness
# 158 161 Act act
# 151 153 BinaryPredicate of
# 105 133 BinaryPredicate is incapable of appreciating
# 165 208 Act acting in accordance with such appreciation
# 162 164 FunctionOperation or
# 209 215 BinaryPredicate due to
# 218 249 Attribute pathological emotional disorder
# 251 282 Attribute profound consciousness disorder
# 284 297 Attribute mental defect
# 301 340 Attribute any other serious emotional abnormality
# 342 361 UnaryPredicate acts without guilt.
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/184a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/306b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/229.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/153.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/235.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/324a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/036.ann
# 29 36 Bob Members
# 37 39 FunctionOperation of
# 44 74 Organization Bundestag (Federal Parliament)
# 80 96 Organization Federal Assembly
# 97 99 FunctionOperation or
# 102 148 Organization legislative body of a Land (constituent state)
# 150 167 BinaryPredicate may at no time be
# 168 188 Bob subject to liability
# 189 208 Attribute outside of the body
# 209 219 BinaryPredicate because of
# 220 230 UnaryPredicate their vote
# 231 233 FunctionOperation or
# 234 278 UnaryPredicate an utterance which they made within the body
# 279 281 FunctionOperation or
# 282 303 UnaryPredicate one of its committees
# 305 309 LawLink This
# 310 328 BinaryPredicate shall not apply to
# 329 347 Act slanderous insults
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/310.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/099.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/084.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/034.ann
# 31 38 Bob Whoever
# 40 50 BinaryPredicate faced with
# 54 69 Circumstance imminent danger
# 73 77 UnaryPredicate life
# 79 83 UnaryPredicate limb
# 85 92 UnaryPredicate freedom
# 94 99 UnaryPredicate honor
# 101 109 UnaryPredicate property
# 110 112 FunctionOperation or
# 113 169 UnaryPredicate another legal interest which cannot otherwise be averted
# 171 178 BinaryPredicate commits
# 182 185 Act act
# 186 194 BinaryPredicate to avert
# 199 205 Circumstance danger
# 206 210 BinaryPredicate from
# 211 218 Bob himself
# 219 221 FunctionOperation or
# 222 229 John another
# 231 254 BinaryPredicate does not act unlawfully
# 256 258 FunctionOperation if
# 260 273 BinaryPredicate upon weighing
# 278 299 UnaryPredicate conflicting interests
# 301 343 UnaryPredicate in particular the affected legal interests
# 344 347 FunctionOperation and
# 352 385 UnaryPredicate degree of danger threatening them
# 391 409 Attribute protected interest
# 410 433 BinaryPredicate substantially outweighs
# 438 457 Attribute one interfered with
# 459 463 LawLink This
# 464 475 BinaryPredicate shall apply
# 477 484 Circumstance however
# 486 509 BinaryPredicate only to the extent that
# 514 517 Act act
# 518 520 BinaryPredicate is
# 523 542 Attribute proportionate means
# 543 551 BinaryPredicate to avert
# 556 562 Circumstance danger
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/070b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/337.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/043.ann
# 0 17 LawLink 43 subsection (1)
# 19 23 UnaryPredicate sent
# 25
#  26 LawLink 3
# 28 51 UnaryPredicate shall apply accordingly
# 58 60 FunctionOperation If
# 64 84 Judgement aggregate punishment
# 85 105 BinaryPredicate is to be formed from
# 106 118 Judgement imprisonment
# 119 122 FunctionOperation and
# 125 129 Judgement fine
# 131 135 FunctionOperation then
# 136 150 Judgement one daily rate
# 151 165 BinaryPredicate corresponds to
# 166 186 Judgement one day imprisonment
# 187 212 BinaryPredicate in determining the sum of
# 217 239 Judgement individual punishments
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/299.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/129a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/070.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/241a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/108b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/314a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/024.ann
# 20 27 Bob Whoever
# 28 70 BinaryPredicate voluntarily renounces further execution of
# 75 78 Act act
# 79 81 FunctionOperation or
# 95 105 NPA completion
# 82 94 BinaryPredicate prevents its
# 106 131 BinaryPredicate shall not be punished for
# 135 142 Act attempt
# 144 146 FunctionOperation If
# 151 154 Act act
# 155 171 UnaryPredicate is not completed
# 172 178 BinaryPredicate due in
# 179 206 LawCorpus no part to the contribution
# 207 209 BinaryPredicate of
# 214 230 John abandoning party
# 231 233 Bob he
# 234 258 BinaryPredicate shall not be punished if
# 259 261 Bob he
# 262 267 BinaryPredicate makes
# 268 277 Attribute voluntary
# 282 289 Attribute earnest
# 290 297 NPA efforts
# 278 281 FunctionOperation and
# 298 312 BinaryPredicate to prevent its
# 313 323 NPA completion
# 330 346 FunctionOperation If more than one
# 347 353 Bob person
# 354 368 BinaryPredicate participate in
# 373 376 Act act
# 378 385 John whoever
# 386 406 BinaryPredicate voluntarily prevents
# 407 410 Act its
# 411 421 NPA completion
# 422 446 BinaryPredicate will not be punished for
# 450 457 NPA attempt
# 467 470 John his
# 471 480 Attribute voluntary
# 485 492 Attribute earnest
# 493 500 NPA efforts
# 501 511 BinaryPredicate to prevent
# 516 526 NPA completion
# 527 529 BinaryPredicate of
# 534 537 Act act
# 538 555 BinaryPredicate shall suffice for
# 556 581 Judgement exemption from punishment
# 583 585 FunctionOperation if
# 590 593 Act act
# 594 628 BinaryPredicate is not completed due in no part to
# 629 632 John his
# 633 645 NPA contribution
# 646 648 FunctionOperation or
# 649 678 BinaryPredicate is committed independently of
# 679 682 John his
# 683 706 BinaryPredicate earlier contribution to
# 711 714 Act act
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/247.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/189.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/180b.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/079a.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/114.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/178.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/252.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/319.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/327.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/256.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/253.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/054.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/171.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/049.ann
# 51 53 FunctionOperation If
# 54 64 Judgement mitigation
# 65 78 BinaryPredicate is prescribed
# 79 81 FunctionOperation or
# 82 97 BinaryPredicate permitted under
# 103 112 LawCorpus provision
# 114 118 FunctionOperation then
# 123 132 LawLink following
# 133 147 BinaryPredicate shall apply to
# 148 163 Judgement such mitigation
# 169 211 Judgement Imprisonment for not less than three years
# 212 235 BinaryPredicate shall take the place of
# 236 257 Judgement imprisonment for life
# 263 274 UnaryPredicate In cases of
# 275 305 Judgement imprisonment for a fixed term,
# 306 327 Judgement at most three-fourths
# 328 330 BinaryPredicate of
# 335 347 Judgement maximum term
# 349 372 UnaryPredicate provided may be imposed
# 374 384 UnaryPredicate In case of
# 387 391 Judgement fine
# 396 415 BinaryPredicate same shall apply to
# 420 449 Judgement maximum number of daily rates
# 458 496 Judgement increased minimum term of imprisonment
# 497 513 BinaryPredicate shall be reduced
# 516 530 UnaryPredicate in the case of
# 533 580 Judgement minimum term of ten or five years, to two years
# 583 593 UnaryPredicate in case of
# 596 645 Judgement minimum term of three or two years, to six months
# 648 658 UnaryPredicate in case of
# 661 702 Judgement minimum term of one year, to three months
# 705 722 UnaryPredicate in other cases to
# 727 744 Judgement statutory minimum
# 751 753 FunctionOperation If
# 758 763 Organization court
# 764 794 BinaryPredicate may in its discretion mitigate
# 799 809 Judgement punishment
# 810 821 BinaryPredicate pursuant to
# 824 828 LawCorpus norm
# 829 844 BinaryPredicate which refers to
# 845 859 LawCorpus this provision
# 861 865 FunctionOperation then
# 866 868 Organization it
# 869 879 BinaryPredicate may reduce
# 884 894 Judgement punishment
# 895 897 BinaryPredicate to
# 902 919 Judgement statutory minimum
# 920 922 FunctionOperation or
# 923 936 Judgement impose a fine
# 937 947 BinaryPredicate instead of
# 948 960 Judgement imprisonment
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/008.ann
# 19 25 Act An act
# 26 50 BinaryPredicate is committed at the time
# 51 94 Bob the perpetrator or the inciter or accessory
# 95 100 UnaryPredicate acted
# 102 126 BinaryPredicate or in case of n omission
# 128 145 Act should have acted
# 147 155 UnaryPredicate The time
# 156 178 UnaryPredicate when the result occurs
# 179 199 UnaryPredicate is not determinative
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/315.ann
# /home/mlc/BobGoesToJail/corpus/lawTexts_en/074b.ann
